# %% [markdown]
# # Purpose: Thermal Camera Application in AFP for ILSS Predictive Model
# # Date: 05/2025
# # UNSW Sydney / EPFL
# # Code: Assier de Pompignan Leo

# %%
# Code used to train the ILSS Predictive Model
import os
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv2D, MaxPooling2D, Flatten, TimeDistributed, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.sequence import pad_sequences
from ultralytics import YOLO  # Import from ultralytics

# Load the trained YOLO model from ultralytics
print("Loading YOLO model...")
yolo_model = YOLO(r'Path_to_YOLO_model\runs\segment\train\weights\best.pt')

# Load the Excel file containing ILSS values
excel_path = r'Path_to_YOLO_model\Train_dataset.xlsx'
print(f"Loading Excel data from {excel_path}...")
df = pd.read_excel(excel_path)

# Function to extract frames from a video and crop ROI using YOLO
def extract_frames(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform YOLO detection
        results = yolo_model(frame)[0]  # Get first result from the list

        # Access detections
        boxes = results.boxes

        if boxes is not None and len(boxes) > 0:
            # Use the first detected box
            xyxy = boxes[0].xyxy.cpu().numpy()[0]  # Get [x1, y1, x2, y2]
            x1, y1, x2, y2 = map(int, xyxy)

            # Crop and store the ROI
            cropped_frame = frame[y1:y2, x1:x2]
            frames.append(cropped_frame)

    cap.release()
    print(f"  ➤ Extracted {len(frames)} frames from {os.path.basename(video_path)}")
    return frames

# Prepare the dataset
def prepare_dataset():
    sequences = []
    targets = []
    print("Preparing dataset...")
    for idx, row in df.iterrows():
        video_name = row['Video name']
        print(f"[{idx+1}/{len(df)}] Processing video: {video_name}")
        video_path = os.path.join(r'C:\Users\lesfr\OneDrive\Documents\master epfl\Projet de master\Models\Thermal camera model\Forward\R_CNN_Mask\Mask_RCNN_test\video-dataset_175', video_name + '.mp4')
        
        # Extract frames and preprocess
        frames = extract_frames(video_path)
        frames = [cv2.resize(frame, (224, 224)) for frame in frames]
        frames = np.array(frames) / 255.0  # Normalize frames
        
        # If video frames are shorter than expected, pad them
        sequence_length = 30
        frames = pad_sequences([frames], maxlen=sequence_length, dtype='float32', padding='post', truncating='post')
        
        # Add ILSS as target
        ilss_value = row['ILSS (Mpa)']
        
        sequences.append(frames)
        targets.append(ilss_value)
    
    print("Dataset preparation complete.\n")
    return np.array(sequences), np.array(targets)

# Define the CNN + LSTM model
def create_model():
    print("Creating CNN + LSTM model...")
    model = Sequential()

    # CNN to extract spatial features
    model.add(TimeDistributed(Conv2D(32, (3, 3), activation='relu', input_shape=(None, 224, 224, 3))))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Conv2D(64, (3, 3), activation='relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Conv2D(128, (3, 3), activation='relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Flatten()))

    # LSTM to capture temporal features
    model.add(Bidirectional(LSTM(128, return_sequences=False)))

    # Dense layers for regression
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))  # Regression output

    model.compile(optimizer=Adam(), loss='mean_squared_error', metrics=['mae'])
    
    print("Model created.\n")
    return model

# Prepare data for training
X, y = prepare_dataset()
print(f"Shape of X: {X.shape}, Shape of y: {y.shape}\n")

# Create and train the model
model = create_model()

# Save model during training
checkpoint = ModelCheckpoint('cnn_lstm_ilss_model.h5', save_best_only=True, monitor='val_loss', mode='min')

# Train the model
print("Starting training...\n")
model.fit(X, y, epochs=50, batch_size=4, validation_split=0.2, callbacks=[checkpoint])
print("\nTraining complete.\n")

# Save the model for future predictions
model.save('cnn_lstm_ilss_model.h5')

print("✅ Model trained and saved successfully!")
# Out:
# Loading YOLO model...
# Loading Excel data from C:\Users\lesfr\OneDrive\Documents\master epfl\Projet de master\Models\Thermal camera model\Forward\R_CNN_Mask\Mask_RCNN_test\Train_dataset.xlsx...
# Preparing dataset...
# [1/22] Processing video: T1
#
# 0: 384x480 (no detections), 88.1ms
# Speed: 2.3ms preprocess, 88.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 (no detections), 69.5ms
# Speed: 1.2ms preprocess, 69.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 (no detections), 54.1ms
# Speed: 1.0ms preprocess, 54.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 (no detections), 54.0ms
# Speed: 0.9ms preprocess, 54.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Nozzle, 52.3ms
# Speed: 1.0ms preprocess, 52.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Nozzle, 53.2ms
# Speed: 1.0ms preprocess, 53.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 54.6ms
# Speed: 1.1ms preprocess, 54.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 50.6ms
# Speed: 1.1ms preprocess, 50.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 48.8ms
# Speed: 1.2ms preprocess, 48.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 46.4ms
# Speed: 0.9ms preprocess, 46.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 62.8ms
# Speed: 1.2ms preprocess, 62.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 47.1ms
# Speed: 1.0ms preprocess, 47.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 53.7ms
# Speed: 1.2ms preprocess, 53.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 82.4ms
# Speed: 0.9ms preprocess, 82.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 52.9ms
# Speed: 1.1ms preprocess, 52.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 46.8ms
# Speed: 1.0ms preprocess, 46.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 72.2ms
# Speed: 1.1ms preprocess, 72.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 75.7ms
# Speed: 1.1ms preprocess, 75.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 76.5ms
# Speed: 0.9ms preprocess, 76.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 69.5ms
# Speed: 1.0ms preprocess, 69.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 70.1ms
# Speed: 1.0ms preprocess, 70.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 69.0ms
# Speed: 0.9ms preprocess, 69.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 74.8ms
# Speed: 0.9ms preprocess, 74.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 72.8ms
# Speed: 1.0ms preprocess, 72.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 71.5ms
# Speed: 1.0ms preprocess, 71.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 77.5ms
# Speed: 1.1ms preprocess, 77.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 72.7ms
# Speed: 1.0ms preprocess, 72.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 71.1ms
# Speed: 0.9ms preprocess, 71.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 71.2ms
# Speed: 1.0ms preprocess, 71.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 88.2ms
# Speed: 0.9ms preprocess, 88.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 61.0ms
# Speed: 1.1ms preprocess, 61.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 47.7ms
# Speed: 1.2ms preprocess, 47.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 46.7ms
# Speed: 1.1ms preprocess, 46.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 43.0ms
# Speed: 0.9ms preprocess, 43.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 46.0ms
# Speed: 0.9ms preprocess, 46.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 45.1ms
# Speed: 1.1ms preprocess, 45.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 45.4ms
# Speed: 1.2ms preprocess, 45.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 45.4ms
# Speed: 1.1ms preprocess, 45.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Roller, 1 Nozzle,
1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 75.8ms
# Speed: 0.9ms preprocess, 75.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 71.4ms
# Speed: 1.0ms preprocess, 71.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 69.0ms
# Speed: 1.1ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 70.5ms
# Speed: 1.1ms preprocess, 70.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 71.3ms
# Speed: 0.9ms preprocess, 71.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 70.5ms
# Speed: 1.0ms preprocess, 70.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 72.9ms
# Speed: 1.1ms preprocess, 72.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 74.4ms
# Speed: 0.9ms preprocess, 74.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 69.2ms
# Speed: 1.0ms preprocess, 69.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 69.1ms
# Speed: 1.0ms preprocess, 69.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 56.8ms
# Speed: 1.0ms preprocess, 56.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 60.4ms
# Speed: 1.0ms preprocess, 60.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 54.9ms
# Speed: 0.9ms preprocess, 54.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 50.3ms
# Speed: 1.1ms preprocess, 50.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 74.0ms
# Speed: 1.1ms preprocess, 74.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 63.0ms
# Speed: 1.2ms preprocess, 63.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 63.7ms
# Speed: 1.1ms preprocess, 63.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 48.9ms
# Speed: 1.1ms preprocess, 48.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 57.3ms
# Speed: 1.2ms preprocess, 57.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 60.6ms
# Speed: 1.0ms preprocess, 60.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 59.0ms
# Speed: 1.1ms preprocess, 59.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 50.5ms
# Speed: 1.2ms preprocess, 50.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 61.7ms
# Speed: 1.1ms preprocess, 61.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 61.1ms
# Speed: 1.2ms preprocess, 61.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 53.9ms
# Speed: 1.1ms preprocess, 53.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 48.0ms
# Speed: 1.1ms preprocess, 48.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 56.1ms
# Speed: 1.0ms preprocess, 56.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 64.7ms
# Speed: 1.2ms preprocess, 64.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 69.5ms
# Speed: 1.2ms preprocess, 69.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 65.4ms
# Speed: 1.3ms preprocess, 65.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.9ms
# Speed: 0.9ms preprocess, 51.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.4ms
# Speed: 1.0ms preprocess, 51.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 49.1ms
# Speed: 1.1ms preprocess, 49.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 48.0ms
# Speed: 1.2ms preprocess, 48.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 48.5ms
# Speed: 1.2ms preprocess, 48.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 47.3ms
# Speed: 1.2ms preprocess, 47.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.1ms
# Speed: 0.9ms preprocess, 51.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 58.4ms
# Speed: 1.3ms preprocess, 58.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 47.3ms
# Speed: 1.1ms preprocess, 47.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 47.0ms
# Speed: 1.1ms preprocess, 47.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 55.3ms
# Speed: 1.0ms preprocess, 55.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 57.8ms
# Speed: 1.2ms preprocess, 57.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 58.2ms
# Speed: 1.1ms preprocess, 58.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 55.3ms
# Speed: 1.1ms preprocess, 55.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.5ms
# Speed: 1.1ms preprocess, 51.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 49.2ms
# Speed: 1.1ms preprocess, 49.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 48.2ms
# Speed: 1.1ms preprocess, 48.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 63.2ms
# Speed: 1.0ms preprocess, 63.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle,
5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 45.3ms
# Speed: 1.1ms preprocess, 45.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 55.9ms
# Speed: 1.1ms preprocess, 55.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.2ms
# Speed: 1.2ms preprocess, 51.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 57.1ms
# Speed: 1.2ms preprocess, 57.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.7ms
# Speed: 1.1ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 52.6ms
# Speed: 1.0ms preprocess, 52.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 48.7ms
# Speed: 1.0ms preprocess, 48.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 47.6ms
# Speed: 1.0ms preprocess, 47.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 47.5ms
# Speed: 1.0ms preprocess, 47.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 57.5ms
# Speed: 1.1ms preprocess, 57.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 54.0ms
# Speed: 1.3ms preprocess, 54.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.8ms
# Speed: 1.2ms preprocess, 49.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 48.3ms
# Speed: 1.2ms preprocess, 48.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 46.0ms
# Speed: 0.8ms preprocess, 46.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 52.2ms
# Speed: 1.3ms preprocess, 52.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 50.6ms
# Speed: 1.2ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 59.0ms
# Speed: 1.1ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.5ms
# Speed: 1.3ms preprocess, 49.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 47.8ms
# Speed: 0.9ms preprocess, 47.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 46.8ms
# Speed: 0.9ms preprocess, 46.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 47.2ms
# Speed: 1.1ms preprocess, 47.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 63.1ms
# Speed: 0.9ms preprocess, 63.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.4ms
# Speed: 1.3ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.9ms
# Speed: 0.9ms preprocess, 51.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.0ms
# Speed: 1.0ms preprocess, 49.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 46.1ms
# Speed: 0.9ms preprocess, 46.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 56.0ms
# Speed: 0.9ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 60.6ms
# Speed: 1.2ms preprocess, 60.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 67.9ms
# Speed: 1.0ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 68.3ms
# Speed: 1.4ms preprocess, 68.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 56.7ms
# Speed: 1.0ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 56.9ms
# Speed: 1.0ms preprocess, 56.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 48.2ms
# Speed: 1.2ms preprocess, 48.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 47.2ms
# Speed: 1.3ms preprocess, 47.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 48.4ms
# Speed: 1.2ms preprocess, 48.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.6ms
# Speed: 1.1ms preprocess, 49.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 50.2ms
# Speed: 1.2ms preprocess, 50.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 54.5ms
# Speed: 1.2ms preprocess, 54.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 55.2ms
# Speed: 1.0ms preprocess, 55.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 71.7ms
# Speed: 1.1ms preprocess, 71.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 60.4ms
# Speed: 1.1ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 53.5ms
# Speed: 1.1ms preprocess, 53.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 54.1ms
# Speed: 1.1ms preprocess, 54.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.9ms
# Speed: 1.1ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.4ms
# Speed: 1.1ms preprocess, 51.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 50.6ms
# Speed: 1.0ms preprocess, 50.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.8ms
# Speed: 1.4ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 59.2ms
# Speed: 0.9ms preprocess, 59.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 50.1ms
# Speed: 1.1ms preprocess, 50.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 48.5ms
# Speed: 1.1ms preprocess, 48.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 50.1ms
# Speed: 1.0ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.4ms
# Speed: 1.1ms preprocess, 49.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 47.1ms
# Speed: 0.9ms preprocess, 47.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 54.8ms
# Speed: 0.9ms preprocess, 54.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 56.9ms
# Speed: 1.1ms preprocess, 56.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 45.4ms
# Speed: 1.3ms preprocess, 45.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 46.2ms
# Speed: 0.9ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 66.7ms
# Speed: 0.9ms preprocess, 66.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 63.7ms
# Speed: 1.1ms preprocess, 63.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.3ms
# Speed: 1.2ms preprocess, 51.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 63.3ms
# Speed: 1.0ms preprocess, 63.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 76.2ms
# Speed: 1.3ms preprocess, 76.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 68.2ms
# Speed: 0.9ms preprocess, 68.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 69.7ms
# Speed: 0.9ms preprocess, 69.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 74.3ms
# Speed: 1.0ms preprocess, 74.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 75.1ms
# Speed: 1.0ms preprocess, 75.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 79.1ms
# Speed: 1.0ms preprocess, 79.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 84.4ms
# Speed: 1.0ms preprocess, 84.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 75.9ms
# Speed: 1.1ms preprocess, 75.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 72.3ms
# Speed: 1.0ms preprocess, 72.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 74.2ms
# Speed: 0.9ms preprocess, 74.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 77.1ms
# Speed: 0.9ms preprocess, 77.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 68.5ms
# Speed: 1.1ms preprocess, 68.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 78.2ms
# Speed: 1.0ms preprocess, 78.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 83.4ms
# Speed: 1.1ms preprocess, 83.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 54.5ms
# Speed: 1.2ms preprocess, 54.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 54.8ms
# Speed: 1.0ms preprocess, 54.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 52.4ms
# Speed: 1.0ms preprocess, 52.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 59.4ms
# Speed: 0.8ms preprocess, 59.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 53.8ms
# Speed: 1.1ms preprocess, 53.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Nozzle, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 2 Nozzles, 60.1ms
# Speed: 1.2ms preprocess, 60.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 2 Nozzles, 64.6ms
# Speed: 1.1ms preprocess, 64.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 57.5ms
# Speed: 1.1ms preprocess, 57.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 53.2ms
# Speed: 1.3ms preprocess, 53.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 53.1ms
# Speed: 1.2ms preprocess, 53.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 50.9ms
# Speed: 0.9ms preprocess, 50.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 54.7ms
# Speed: 1.2ms preprocess, 54.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 59.4ms
# Speed: 1.2ms preprocess, 59.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.2ms
# Speed: 1.1ms preprocess, 51.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 50.9ms
# Speed: 1.2ms preprocess, 50.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 71.1ms
# Speed: 1.1ms preprocess, 71.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 75.1ms
# Speed: 0.9ms preprocess, 75.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 53.1ms
# Speed: 1.0ms preprocess, 53.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 62.5ms
# Speed: 1.1ms preprocess, 62.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 53.2ms
# Speed: 1.2ms preprocess, 53.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 53.0ms
# Speed: 1.1ms preprocess, 53.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 47.3ms
# Speed: 0.9ms preprocess, 47.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 52.1ms
# Speed: 1.0ms preprocess, 52.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 50.8ms
# Speed: 1.2ms preprocess, 50.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 60.9ms
# Speed: 1.1ms preprocess, 60.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 53.6ms
# Speed: 1.2ms preprocess, 53.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 49.3ms
# Speed: 1.1ms preprocess, 49.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 49.5ms
# Speed: 1.1ms preprocess, 49.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.0ms
# Speed: 1.1ms preprocess, 51.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 70.5ms
# Speed: 1.1ms preprocess, 70.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 67.6ms
# Speed: 1.1ms preprocess, 67.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 63.4ms
# Speed: 1.1ms preprocess, 63.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 63.2ms
# Speed: 1.0ms preprocess, 63.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 58.3ms
# Speed: 1.0ms preprocess, 58.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 53.4ms
# Speed: 0.9ms preprocess, 53.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 59.8ms
# Speed: 1.1ms preprocess, 59.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# ...
#
# 0: 384x480 1 Sample, 94.9ms
# Speed: 1.2ms preprocess, 94.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 95.2ms
# Speed: 1.2ms preprocess, 95.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 100.2ms
# Speed: 1.2ms preprocess, 100.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 96.5ms
# Speed: 1.5ms preprocess, 96.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 102.7ms
# Speed: 1.4ms preprocess, 102.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 82.5ms
# Speed: 1.2ms preprocess, 82.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 83.0ms
# Speed: 1.1ms preprocess, 83.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 79.2ms
# Speed: 1.0ms preprocess, 79.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 79.7ms
# Speed: 1.1ms preprocess, 79.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 76.1ms
# Speed: 1.1ms preprocess, 76.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 76.4ms
# Speed: 1.1ms preprocess, 76.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 79.4ms
# Speed: 1.2ms preprocess, 79.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 74.8ms
# Speed: 1.0ms preprocess, 74.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 75.6ms
# Speed: 1.0ms preprocess, 75.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 74.3ms
# Speed: 1.1ms preprocess, 74.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 76.4ms
# Speed: 1.1ms preprocess, 76.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 75.4ms
# Speed: 1.1ms preprocess, 75.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 79.0ms
# Speed: 1.1ms preprocess, 79.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 82.9ms
# Speed: 1.2ms preprocess, 82.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 78.9ms
# Speed: 1.2ms preprocess, 78.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 78.0ms
# Speed: 1.0ms preprocess, 78.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 73.1ms
# Speed: 1.0ms preprocess, 73.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 78.8ms
# Speed: 1.2ms preprocess, 78.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 74.3ms
# Speed: 1.2ms preprocess, 74.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 70.6ms
# Speed: 1.1ms preprocess, 70.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 76.4ms
# Speed: 1.2ms preprocess, 76.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 73.9ms
# Speed: 1.1ms preprocess, 73.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 76.3ms
# Speed: 1.0ms preprocess, 76.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 80.8ms
# Speed: 1.0ms preprocess, 80.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 84.2ms
# Speed: 1.4ms preprocess, 84.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 74.7ms
# Speed: 1.1ms preprocess, 74.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 83.4ms
# Speed: 1.3ms preprocess, 83.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 81.7ms
# Speed: 1.0ms preprocess, 81.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 79.6ms
# Speed: 1.1ms preprocess, 79.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 77.1ms
# Speed: 1.1ms preprocess, 77.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 100.1ms
# Speed: 1.0ms preprocess, 100.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 88.0ms
# Speed: 1.2ms preprocess, 88.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 82.6ms
# Speed: 1.2ms preprocess, 82.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 80.5ms
# Speed: 1.1ms preprocess, 80.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 74.3ms
# Speed: 1.0ms preprocess, 74.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample,
1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 80.5ms
# Speed: 1.1ms preprocess, 80.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 77.9ms
# Speed: 1.1ms preprocess, 77.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 78.2ms
# Speed: 1.2ms preprocess, 78.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 73.9ms
# Speed: 1.1ms preprocess, 73.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 76.2ms
# Speed: 1.3ms preprocess, 76.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 76.7ms
# Speed: 1.1ms preprocess, 76.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 77.8ms
# Speed: 1.0ms preprocess, 77.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 84.1ms
# Speed: 1.2ms preprocess, 84.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 86.2ms
# Speed: 1.1ms preprocess, 86.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 105.5ms
# Speed: 1.3ms preprocess, 105.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 83.2ms
# Speed: 1.2ms preprocess, 83.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 81.8ms
# Speed: 1.2ms preprocess, 81.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 77.5ms
# Speed: 1.1ms preprocess, 77.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 76.6ms
# Speed: 1.1ms preprocess, 76.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 76.2ms
# Speed: 1.0ms preprocess, 76.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 74.6ms
# Speed: 1.2ms preprocess, 74.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 75.9ms
# Speed: 1.1ms preprocess, 75.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 73.7ms
# Speed: 1.1ms preprocess, 73.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 74.9ms
# Speed: 1.1ms preprocess, 74.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 75.6ms
# Speed: 1.2ms preprocess, 75.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 73.0ms
# Speed: 1.1ms preprocess, 73.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 73.0ms
# Speed: 1.1ms preprocess, 73.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 76.0ms
# Speed: 1.2ms preprocess, 76.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 75.9ms
# Speed: 1.1ms preprocess, 75.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 84.8ms
# Speed: 1.0ms preprocess, 84.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 88.4ms

# %%
# Code used to run inference using the ILSS Predictive Model
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from ultralytics import YOLO  # Import from ultralytics

# Load the trained YOLO model from ultralytics
yolo_model = YOLO(r'Path_to_YOLO_model\runs\segment\train\weights\best.pt')

# Load the trained CNN + LSTM model
model = load_model('cnn_lstm_ilss_model.h5')

# Function to extract frames from a video and crop ROI using YOLO
def extract_frames(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform YOLO detection
        results = yolo_model(frame)[0]  # Get first result from the list

        # Access detections
        boxes = results.boxes

        if boxes is not None and len(boxes) > 0:
            # Use the first detected box
            xyxy = boxes[0].xyxy.cpu().numpy()[0]  # Get [x1, y1, x2, y2]
            x1, y1, x2, y2 = map(int, xyxy)

            # Crop and store the ROI
            cropped_frame = frame[y1:y2, x1:x2]
            frames.append(cropped_frame)

    cap.release()
    return frames


# Predict ILSS value for a new video
def predict_ilss(video_path):
    frames = extract_frames(video_path)
    frames = [cv2.resize(frame, (224, 224)) for frame in frames]
    frames = np.array(frames) / 255.0  # Normalize frames
    
    # If video frames are shorter than expected, pad them
    sequence_length = 30
    frames = pad_sequences([frames], maxlen=sequence_length, dtype='float32', padding='post', truncating='post')

    # Predict ILSS value
    ilss_value = model.predict(frames)
    return ilss_value[0][0]

# Define the video path and name
video_name = 'T1'  # Change this to your desired video name (e.g., 'T1')
video_path = r'Path_to_YOLO_model\video_dataset\\' + video_name + '.mp4'

# Predict the ILSS value
predicted_ilss = predict_ilss(video_path)
print(f"Predicted ILSS value for {video_name}: {predicted_ilss}")
