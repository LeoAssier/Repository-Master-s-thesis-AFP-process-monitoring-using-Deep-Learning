# %%
# Purpose: Thermal Camera Application in AFP for Deposition Rate Recognition 
# Date: 05/2025
# UNSW Sydney / EPFL
# Code: Assier de Pompignan Leo

# Note: Change the time.sleep() to suit your computer specification (Default: 0.3)

# %%
# Deposition Rate Recognition model (without vectors)
from ultralytics import YOLO
import cv2
import numpy as np
import time
from scipy.spatial.distance import pdist, cdist

# Load the trained model
model = YOLO(r"Path_to_YOLO_model\runs\segment\train\weights\best.pt")
# Define video path
video_path = r"Path_to_\video_dataset\T2.mp4"

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get total number of frames in the video
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = cap.get(cv2.CAP_PROP_FPS)
frame_time_s = 1 / fps if fps > 0 else 0.033
print(f"Total frames: {total_frames}, FPS: {fps:.2f}, Frame time: {frame_time_s:.3f}s")

frame_count = 0

touching_frames_list = []  
touching_frames = 0
previous_touching_state = False
gap_frames = 0
max_gap = 5  # Maximum allowed gap frames to merge passes

touch_threshold_factor = 0.2  # Touching threshold as a percentage of roller size
confidence_threshold = 0.5  # Minimum confidence for detection
sample_length_mm = 210  # Reference length

# Loop through frames
while True:
    ret, frame = cap.read()
    if not ret:
        break  
    
    frame_count += 1
    
    results = model(frame)
    best_sample_mask = None
    best_roller_mask = None
    max_sample_conf = 0
    max_roller_conf = 0

    # Process detections
    for result in results:
        if result.masks is None:
            continue  # Skip if no masks detected

        for box, mask in zip(result.boxes, result.masks.xy):
            class_id = int(box.cls)
            confidence = float(box.conf)
            if confidence < confidence_threshold:
                continue  
            
            if class_id == 0 and confidence > max_sample_conf:  # Sample
                best_sample_mask = np.array(mask)
                max_sample_conf = confidence
            elif class_id == 1 and confidence > max_roller_conf:  # Roller
                best_roller_mask = np.array(mask)
                max_roller_conf = confidence
    
    is_touching = False
    
    if best_sample_mask is not None and best_roller_mask is not None:
        # Compute the largest distance in the roller mask
        roller_size = np.max(pdist(best_roller_mask))  # Max pairwise distance
        touch_threshold = touch_threshold_factor * roller_size  # Threshold for touching

        # Compute the minimum distance between sample and roller edges
        min_edge_distance = np.min(cdist(best_sample_mask, best_roller_mask))

        if min_edge_distance <= touch_threshold:
            is_touching = True

        print(f"Frame {frame_count}: Touching = {'Yes' if is_touching else 'No'}")
        print(f"Frame {frame_count}: Minimum Edge Distance = {min_edge_distance:.2f} pixels")
        print(f"Frame {frame_count}: Roller Size = {roller_size:.2f} pixels")
    else:
        print(f"Frame {frame_count}: One or both objects not detected.")
    
    # Pass tracking logic
    if is_touching:
        if gap_frames > 0 and gap_frames <= max_gap:  
            touching_frames += gap_frames  # Add the missed frames
        
        touching_frames += 1  
        gap_frames = 0  # Reset gap counter
    else:
        if previous_touching_state:  
            gap_frames = 1  # First frame after stopping touching
        elif gap_frames > 0:  
            gap_frames += 1  # Keep counting the gap
    
        if gap_frames > max_gap:  # If gap exceeds max allowed, finalize the previous pass
            if touching_frames > 0:
                touching_frames_list.append(touching_frames)
                print(f"Deposition Layer Completed: {touching_frames} consecutive touching frames")
                touching_frames = 0  
            gap_frames = 0  
    
    previous_touching_state = is_touching  
    time.sleep(0.3)

# Final pass check
if touching_frames > 0:
    touching_frames_list.append(touching_frames)
    print(f"Deposition Layer Completed: {touching_frames} consecutive touching frames")

# Filter out short passes based on 20% of the longest pass
if touching_frames_list:
    max_pass = max(touching_frames_list)
    min_frames_per_pass = 0.2 * max_pass  
    touching_frames_list = [pass_frames for pass_frames in touching_frames_list if pass_frames >= min_frames_per_pass]

# Compute statistics
if touching_frames_list:
    avg_touching_frames = sum(touching_frames_list) / len(touching_frames_list)
    roller_speed = sample_length_mm / (avg_touching_frames * frame_time_s)

    print("\n--- Deposition Statistics ---")
    print(f"Total deposition passes: {len(touching_frames_list)}")
    print(f"Touching frames per pass: {touching_frames_list}")
    print(f"Average touching frames: {avg_touching_frames:.2f} frames")
    print(f"Computed roller speed: {roller_speed:.2f} mm/s")

cap.release()
# Out:
# Total frames: 3300, FPS: 30.00, Frame time: 0.033s
#
# 0: 384x480 1 Nozzle, 36.4ms
# Speed: 4.3ms preprocess, 36.4ms inference, 108.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 1: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 2: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 8.7ms
# Speed: 1.3ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 5.0ms
# Speed: 0.8ms preprocess, 5.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 4: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 5.0ms
# Speed: 0.8ms preprocess, 5.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 5: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 6.2ms
# Speed: 0.9ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 6: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 7: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 5.5ms
# Speed: 0.9ms preprocess, 5.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 8: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 5.5ms
# Speed: 0.8ms preprocess, 5.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 9: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 5.5ms
# Speed: 0.8ms preprocess, 5.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 10: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 5.1ms
# Speed: 0.8ms preprocess, 5.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 11: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 12: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 6.6ms
# Speed: 1.0ms preprocess, 6.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 13: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 4.9ms
# Speed: 2.0ms preprocess, 4.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 14: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 9.2ms
# Speed: 1.2ms preprocess, 9.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 15: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 5.2ms
# Speed: 0.9ms preprocess, 5.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 16: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 17: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 18: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 17.1ms
# Speed: 1.1ms preprocess, 17.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 19: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 19.2ms
# Speed: 1.2ms preprocess, 19.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 20: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 20.1ms
# Speed: 0.9ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 21: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 22: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.0ms
# Speed: 1.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 23: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 24: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.4ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 25: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 26: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.8ms
# Speed: 1.4ms preprocess, 21.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 27: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 28: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 29: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 30: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 31: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 2.1ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 32: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.7ms preprocess, 21.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 33: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 22.0ms
# Speed: 2.8ms preprocess, 22.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 34: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 35: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 36: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 1.5ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 37: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 38: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 39: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.3ms preprocess, 21.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 40: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 41: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 1.9ms preprocess, 21.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 42: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.3ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 43: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.4ms
# Speed: 1.1ms preprocess, 21.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 44: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 45: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 46: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 47: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 48: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 49: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 50: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 51: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 52: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 1.0ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 53: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.1ms
# Speed: 1.5ms preprocess, 21.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 54: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 2.5ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 55: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 56: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 22.9ms
# Speed: 2.9ms preprocess, 22.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 57: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 58: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.1ms
# Speed: 1.5ms preprocess, 21.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 59: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.3ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 60: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 61: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 1.0ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 62: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.4ms
# Speed: 1.4ms preprocess, 21.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 63: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 2.3ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 64: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 65: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 66: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 67: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 68: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 1.3ms preprocess, 21.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 69: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 70: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 71: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 72: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.4ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 73: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 74: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.5ms
# Speed: 1.6ms preprocess, 21.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 75: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 76: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 77: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.4ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 78: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 79: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 2.4ms preprocess, 21.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 80: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 81: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 1.3ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 82: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 83: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.6ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 84: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 2.7ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 85: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 86: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 3.5ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 87: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.5ms
# Speed: 1.7ms preprocess, 21.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 88: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 89: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.4ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 90: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 91: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.9ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 92: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.8ms preprocess, 21.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 93: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 3.1ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 94: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.9ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 95: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 96: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 0.9ms preprocess, 21.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 97: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 2.8ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 98: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.6ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 99: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 100: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.5ms
# Speed: 3.4ms preprocess, 21.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 101: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.5ms
# Speed: 1.9ms preprocess, 21.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 102: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 3.1ms preprocess, 21.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 103: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 3.4ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 104: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 2.6ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 105: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 106: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.5ms preprocess, 21.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 107: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 108: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 3.7ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 109: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 2.4ms preprocess, 21.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 110: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 4.2ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 111: One or both objects not detected.
#
# 0: 384x480 (no detections), 22.2ms
# Speed: 3.0ms preprocess, 22.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 112: One or both objects not detected.
#
# 0: 384x480 (no detections), 22.2ms
# Speed: 2.3ms preprocess, 22.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 113: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.6ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 114: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 115: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 1.0ms preprocess, 21.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 116: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 0.9ms preprocess, 21.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 117: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 118: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.0ms
# Speed: 1.3ms preprocess, 21.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 119: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.2ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 120: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 121: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 122: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.6ms preprocess, 21.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 123: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 124: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.5ms
# Speed: 2.2ms preprocess, 21.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 125: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 126: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.7ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 127: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 128: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.2ms
# Speed: 1.4ms preprocess, 21.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 129: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.4ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 130: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.6ms preprocess, 21.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 131: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 132: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 133: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.8ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 134: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.6ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 135: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.9ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 136: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 137: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 138: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 139: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 140: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.4ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 141: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 142: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.4ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 143: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.4ms
# Speed: 3.6ms preprocess, 22.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 144: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 145: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.8ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 146: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 2.8ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 147: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.8ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 148: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 149: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.9ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 150: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.7ms
# Speed: 1.2ms preprocess, 21.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 151: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.7ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 152: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.6ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 153: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 2.6ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 154: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.3ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 155: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.1ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 156: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 2.8ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 157: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.9ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 158: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.5ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 159: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.6ms
# Speed: 3.2ms preprocess, 21.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 160: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 161: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.7ms
# Speed: 3.4ms preprocess, 22.7ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 162: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.1ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 163: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 164: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 165: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 166: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.0ms
# Speed: 0.9ms preprocess, 21.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 167: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.7ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 168: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.8ms
# Speed: 2.2ms preprocess, 23.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 169: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 170: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 171: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 2.2ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 172: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 173: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.4ms preprocess, 21.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 174: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 175: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 2.8ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 176: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.7ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 177: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 178: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.7ms preprocess, 21.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 179: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.7ms
# Speed: 3.7ms preprocess, 21.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 180: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.5ms
# Speed: 2.6ms preprocess, 21.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 181: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.2ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 182: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 183: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 184: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.2ms
# Speed: 2.9ms preprocess, 22.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 185: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 3.3ms preprocess, 21.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 186: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 3.2ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 187: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 188: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 30.0ms
# Speed: 2.7ms preprocess, 30.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 189: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 190: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 191: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 192: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.7ms preprocess, 21.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 193: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.5ms
# Speed: 2.0ms preprocess, 21.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 194: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 195: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 3.0ms preprocess, 21.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 196: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.7ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 197: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 3.1ms preprocess, 21.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 198: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.0ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 199: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 200: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.9ms
# Speed: 2.3ms preprocess, 21.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 201: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 2.9ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 202: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.4ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 203: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.1ms preprocess, 21.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 204: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 205: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.0ms preprocess, 21.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 206: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 207: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.3ms preprocess, 21.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 208: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 209: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 210: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 211: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.5ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 212: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 213: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 214: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 20.9ms
# Speed: 1.2ms preprocess, 20.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 215: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 216: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 217: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 218: One or both objects not detected.
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 219: One or both objects not detected.
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.7ms preprocess, 21.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 220: Touching = Yes
# Frame 220: Minimum Edge Distance = 1.93 pixels
# Frame 220: Roller Size = 25.54 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.5ms preprocess, 21.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 221: One or both objects not detected.
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.3ms preprocess, 21.2ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 222: Touching = Yes
# Frame 222: Minimum Edge Distance = 0.97 pixels
# Frame 222: Roller Size = 27.08 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.7ms preprocess, 21.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 223: Touching = Yes
# Frame 223: Minimum Edge Distance = 0.00 pixels
# Frame 223: Roller Size = 27.65 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.5ms preprocess, 21.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 224: Touching = Yes
# Frame 224: Minimum Edge Distance = 0.00 pixels
# Frame 224: Roller Size = 28.56 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.3ms preprocess, 21.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 225: Touching = Yes
# Frame 225: Minimum Edge Distance = 0.00 pixels
# Frame 225: Roller Size = 28.97 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 226: Touching = Yes
# Frame 226: Minimum Edge Distance = 0.00 pixels
# Frame 226: Roller Size = 28.97 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 227: Touching = Yes
# Frame 227: Minimum Edge Distance = 0.97 pixels
# Frame 227: Roller Size = 27.51 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 228: Touching = Yes
# Frame 228: Minimum Edge Distance = 0.97 pixels
# Frame 228: Roller Size = 25.74 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.6ms preprocess, 21.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 229: Touching = Yes
# Frame 229: Minimum Edge Distance = 0.00 pixels
# Frame 229: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 230: Touching = Yes
# Frame 230: Minimum Edge Distance = 0.00 pixels
# Frame 230: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.4ms preprocess, 21.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 231: Touching = Yes
# Frame 231: Minimum Edge Distance = 0.97 pixels
# Frame 231: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 232: Touching = Yes
# Frame 232: Minimum Edge Distance = 0.97 pixels
# Frame 232: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.5ms
# Speed: 1.6ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 233: Touching = Yes
# Frame 233: Minimum Edge Distance = 0.97 pixels
# Frame 233: Roller Size = 26.03 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.7ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 234: Touching = Yes
# Frame 234: Minimum Edge Distance = 0.97 pixels
# Frame 234: Roller Size = 29.40 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.8ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 235: Touching = Yes
# Frame 235: Minimum Edge Distance = 0.97 pixels
# Frame 235: Roller Size = 29.40 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.1ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 236: Touching = Yes
# Frame 236: Minimum Edge Distance = 0.00 pixels
# Frame 236: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 237: Touching = Yes
# Frame 237: Minimum Edge Distance = 0.00 pixels
# Frame 237: Roller Size = 26.54 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.8ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 238: Touching = Yes
# Frame 238: Minimum Edge Distance = 2.16 pixels
# Frame 238: Roller Size = 26.54 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.4ms
# Speed: 2.7ms preprocess, 21.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 239: Touching = Yes
# Frame 239: Minimum Edge Distance = 1.37 pixels
# Frame 239: Roller Size = 28.56 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.5ms
# Speed: 3.0ms preprocess, 21.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 240: Touching = Yes
# Frame 240: Minimum Edge Distance = 0.00 pixels
# Frame 240: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.0ms preprocess, 21.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 241: Touching = Yes
# Frame 241: Minimum Edge Distance = 0.97 pixels
# Frame 241: Roller Size = 28.97 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 242: Touching = Yes
# Frame 242: Minimum Edge Distance = 0.97 pixels
# Frame 242: Roller Size = 29.40 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.1ms
# Speed: 2.7ms preprocess, 26.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 243: Touching = Yes
# Frame 243: Minimum Edge Distance = 0.97 pixels
# Frame 243: Roller Size = 29.40 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 244: Touching = Yes
# Frame 244: Minimum Edge Distance = 0.00 pixels
# Frame 244: Roller Size = 31.80 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.5ms
# Speed: 3.8ms preprocess, 21.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 245: Touching = Yes
# Frame 245: Minimum Edge Distance = 0.00 pixels
# Frame 245: Roller Size = 28.18 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 3.1ms preprocess, 21.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 246: Touching = Yes
# Frame 246: Minimum Edge Distance = 0.97 pixels
# Frame 246: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.3ms preprocess, 21.3ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 247: Touching = Yes
# Frame 247: Minimum Edge Distance = 0.97 pixels
# Frame 247: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.7ms
# Speed: 3.6ms preprocess, 21.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 248: Touching = Yes
# Frame 248: Minimum Edge Distance = 1.37 pixels
# Frame 248: Roller Size = 27.51 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 3.0ms preprocess, 21.2ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 249: Touching = Yes
# Frame 249: Minimum Edge Distance = 0.00 pixels
# Frame 249: Roller Size = 30.95 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.0ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 250: Touching = Yes
# Frame 250: Minimum Edge Distance = 0.97 pixels
# Frame 250: Roller Size = 27.83 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 251: Touching = Yes
# Frame 251: Minimum Edge Distance = 0.97 pixels
# Frame 251: Roller Size = 29.40 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.9ms preprocess, 21.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 252: Touching = Yes
# Frame 252: Minimum Edge Distance = 0.00 pixels
# Frame 252: Roller Size = 31.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.3ms preprocess, 21.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 253: Touching = Yes
# Frame 253: Minimum Edge Distance = 0.00 pixels
# Frame 253: Roller Size = 33.29 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.3ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 254: Touching = Yes
# Frame 254: Minimum Edge Distance = 1.37 pixels
# Frame 254: Roller Size = 31.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.8ms preprocess, 21.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 255: Touching = Yes
# Frame 255: Minimum Edge Distance = 0.97 pixels
# Frame 255: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.4ms
# Speed: 2.7ms preprocess, 21.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# ...
# Frame 3240: Touching = Yes
# Frame 3240: Minimum Edge Distance = 0.97 pixels
# Frame 3240: Roller Size = 29.02 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3241: Touching = Yes
# Frame 3241: Minimum Edge Distance = 0.00 pixels
# Frame 3241: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3242: Touching = Yes
# Frame 3242: Minimum Edge Distance = 0.00 pixels
# Frame 3242: Roller Size = 31.80 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3243: Touching = Yes
# Frame 3243: Minimum Edge Distance = 0.00 pixels
# Frame 3243: Roller Size = 30.35 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3244: Touching = Yes
# Frame 3244: Minimum Edge Distance = 1.37 pixels
# Frame 3244: Roller Size = 33.29 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 22.3ms
# Speed: 0.9ms preprocess, 22.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3245: Touching = Yes
# Frame 3245: Minimum Edge Distance = 0.00 pixels
# Frame 3245: Roller Size = 31.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3246: Touching = Yes
# Frame 3246: Minimum Edge Distance = 0.97 pixels
# Frame 3246: Roller Size = 31.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3247: Touching = Yes
# Frame 3247: Minimum Edge Distance = 0.00 pixels
# Frame 3247: Roller Size = 28.18 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.4ms
# Speed: 1.4ms preprocess, 21.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3248: Touching = Yes
# Frame 3248: Minimum Edge Distance = 0.00 pixels
# Frame 3248: Roller Size = 28.18 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3249: Touching = Yes
# Frame 3249: Minimum Edge Distance = 0.00 pixels
# Frame 3249: Roller Size = 33.29 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3250: Touching = Yes
# Frame 3250: Minimum Edge Distance = 0.00 pixels
# Frame 3250: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3251: Touching = Yes
# Frame 3251: Minimum Edge Distance = 0.00 pixels
# Frame 3251: Roller Size = 33.29 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3252: Touching = Yes
# Frame 3252: Minimum Edge Distance = 0.00 pixels
# Frame 3252: Roller Size = 32.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3253: Touching = Yes
# Frame 3253: Minimum Edge Distance = 0.97 pixels
# Frame 3253: Roller Size = 32.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3254: Touching = Yes
# Frame 3254: Minimum Edge Distance = 0.00 pixels
# Frame 3254: Roller Size = 32.88 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3255: Touching = Yes
# Frame 3255: Minimum Edge Distance = 0.97 pixels
# Frame 3255: Roller Size = 29.02 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.6ms preprocess, 21.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3256: Touching = Yes
# Frame 3256: Minimum Edge Distance = 0.00 pixels
# Frame 3256: Roller Size = 31.91 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3257: Touching = Yes
# Frame 3257: Minimum Edge Distance = 0.00 pixels
# Frame 3257: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3258: Touching = Yes
# Frame 3258: Minimum Edge Distance = 0.00 pixels
# Frame 3258: Roller Size = 31.80 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3259: Touching = Yes
# Frame 3259: Minimum Edge Distance = 0.00 pixels
# Frame 3259: Roller Size = 28.18 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3260: Touching = Yes
# Frame 3260: Minimum Edge Distance = 0.00 pixels
# Frame 3260: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.2ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3261: Touching = Yes
# Frame 3261: Minimum Edge Distance = 0.97 pixels
# Frame 3261: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 1.6ms preprocess, 21.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3262: Touching = Yes
# Frame 3262: Minimum Edge Distance = 0.00 pixels
# Frame 3262: Roller Size = 32.13 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3263: Touching = Yes
# Frame 3263: Minimum Edge Distance = 0.97 pixels
# Frame 3263: Roller Size = 33.51 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3264: Touching = Yes
# Frame 3264: Minimum Edge Distance = 1.37 pixels
# Frame 3264: Roller Size = 32.00 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3265: Touching = Yes
# Frame 3265: Minimum Edge Distance = 0.00 pixels
# Frame 3265: Roller Size = 33.29 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3266: Touching = Yes
# Frame 3266: Minimum Edge Distance = 0.97 pixels
# Frame 3266: Roller Size = 31.91 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3267: Touching = Yes
# Frame 3267: Minimum Edge Distance = 0.00 pixels
# Frame 3267: Roller Size = 32.88 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.5ms preprocess, 21.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3268: Touching = Yes
# Frame 3268: Minimum Edge Distance = 0.00 pixels
# Frame 3268: Roller Size = 32.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3269: Touching = Yes
# Frame 3269: Minimum Edge Distance = 0.00 pixels
# Frame 3269: Roller Size = 31.91 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3270: Touching = Yes
# Frame 3270: Minimum Edge Distance = 0.00 pixels
# Frame 3270: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3271: Touching = Yes
# Frame 3271: Minimum Edge Distance = 1.37 pixels
# Frame 3271: Roller Size = 31.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.6ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3272: Touching = Yes
# Frame 3272: Minimum Edge Distance = 0.97 pixels
# Frame 3272: Roller Size = 32.13 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.7ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3273: Touching = Yes
# Frame 3273: Minimum Edge Distance = 0.97 pixels
# Frame 3273: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.6ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3274: Touching = Yes
# Frame 3274: Minimum Edge Distance = 0.00 pixels
# Frame 3274: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.1ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3275: Touching = Yes
# Frame 3275: Minimum Edge Distance = 0.00 pixels
# Frame 3275: Roller Size = 35.15 pixels
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3276: Touching = Yes
# Frame 3276: Minimum Edge Distance = 0.97 pixels
# Frame 3276: Roller Size = 33.29 pixels
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3277: Touching = Yes
# Frame 3277: Minimum Edge Distance = 0.97 pixels
# Frame 3277: Roller Size = 37.20 pixels
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3278: Touching = Yes
# Frame 3278: Minimum Edge Distance = 0.00 pixels
# Frame 3278: Roller Size = 37.61 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3279: Touching = Yes
# Frame 3279: Minimum Edge Distance = 0.97 pixels
# Frame 3279: Roller Size = 36.44 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3280: Touching = Yes
# Frame 3280: Minimum Edge Distance = 0.00 pixels
# Frame 3280: Roller Size = 38.50 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3281: Touching = Yes
# Frame 3281: Minimum Edge Distance = 1.37 pixels
# Frame 3281: Roller Size = 39.96 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3282: Touching = Yes
# Frame 3282: Minimum Edge Distance = 0.97 pixels
# Frame 3282: Roller Size = 34.92 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3283: Touching = Yes
# Frame 3283: Minimum Edge Distance = 1.93 pixels
# Frame 3283: Roller Size = 32.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3284: Touching = Yes
# Frame 3284: Minimum Edge Distance = 0.00 pixels
# Frame 3284: Roller Size = 35.77 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3285: Touching = Yes
# Frame 3285: Minimum Edge Distance = 1.93 pixels
# Frame 3285: Roller Size = 34.05 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3286: Touching = Yes
# Frame 3286: Minimum Edge Distance = 1.93 pixels
# Frame 3286: Roller Size = 33.82 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.2ms preprocess, 21.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3287: Touching = Yes
# Frame 3287: Minimum Edge Distance = 0.00 pixels
# Frame 3287: Roller Size = 36.09 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3288: Touching = Yes
# Frame 3288: Minimum Edge Distance = 0.97 pixels
# Frame 3288: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.6ms
# Speed: 1.4ms preprocess, 21.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3289: Touching = Yes
# Frame 3289: Minimum Edge Distance = 0.97 pixels
# Frame 3289: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.2ms preprocess, 21.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3290: Touching = Yes
# Frame 3290: Minimum Edge Distance = 0.97 pixels
# Frame 3290: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 0.9ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3291: Touching = Yes
# Frame 3291: Minimum Edge Distance = 0.97 pixels
# Frame 3291: Roller Size = 39.46 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3292: Touching = Yes
# Frame 3292: Minimum Edge Distance = 0.97 pixels
# Frame 3292: Roller Size = 39.46 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 20.9ms
# Speed: 0.9ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3293: Touching = Yes
# Frame 3293: Minimum Edge Distance = 0.97 pixels
# Frame 3293: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3294: Touching = Yes
# Frame 3294: Minimum Edge Distance = 0.97 pixels
# Frame 3294: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3295: Touching = Yes
# Frame 3295: Minimum Edge Distance = 0.97 pixels
# Frame 3295: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 0.9ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3296: Touching = Yes
# Frame 3296: Minimum Edge Distance = 0.97 pixels
# Frame 3296: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.3ms preprocess, 21.1ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3297: Touching = Yes
# Frame 3297: Minimum Edge Distance = 0.97 pixels
# Frame 3297: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.0ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3298: Touching = Yes
# Frame 3298: Minimum Edge Distance = 0.97 pixels
# Frame 3298: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.1ms
# Speed: 1.0ms preprocess, 21.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3299: Touching = Yes
# Frame 3299: Minimum Edge Distance = 0.97 pixels
# Frame 3299: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 1.1ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3300: Touching = Yes
# Frame 3300: Minimum Edge Distance = 0.97 pixels
# Frame 3300: Roller Size = 36.20 pixels
# Deposition Layer Completed: 155 consecutive touching frames
#
# --- Deposition Statistics ---
# Total deposition passes: 8
# Touching frames per pass: [149, 150, 148, 148, 148, 148, 147, 155]
# Average touching frames: 149.12 frames
# Computed roller speed: 42.25 mm/s

# %%
# Deposition Rate Recognition model (with vectors)
from ultralytics import YOLO
import cv2
import numpy as np
import time
from scipy.spatial.distance import pdist, cdist
from collections import deque


# Load the trained model
model = YOLO(r"Path_to_YOLO_model\runs\segment\train\weights\best.pt")
# Define video path
video_path = r"Path_to_\video_dataset\T2.mp4"
cap = cv2.VideoCapture(video_path)

# Get video info
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = cap.get(cv2.CAP_PROP_FPS)
frame_time_s = 1 / fps if fps > 0 else 0.033
print(f"Total frames: {total_frames}, FPS: {fps:.2f}, Frame time: {frame_time_s:.3f}s")

frame_count = 0

# Parameters
touching_frames_list = []  
touching_frames = 0
previous_touching_state = False
gap_frames = 0
max_gap = 5
touch_threshold_factor = 0.2
confidence_threshold = 0.5
sample_length_mm = 210
angle_threshold = 90  # Degrees

# Tracking history
motion_vectors = []
roller_centers = deque(maxlen=5)

def angle_between(v1, v2):
    """Compute angle in degrees between two vectors."""
    if v1 is None or v2 is None:
        return 0
    if np.linalg.norm(v1) == 0 or np.linalg.norm(v2) == 0:
        return 0
    v1_u = v1 / np.linalg.norm(v1)
    v2_u = v2 / np.linalg.norm(v2)
    dot = np.clip(np.dot(v1_u, v2_u), -1.0, 1.0)
    return np.degrees(np.arccos(dot))

# Process video frame-by-frame
while True:
    ret, frame = cap.read()
    if not ret:
        break  
    
    frame_count += 1
    
    results = model(frame)
    best_sample_mask = None
    best_roller_mask = None
    max_sample_conf = 0
    max_roller_conf = 0

    for result in results:
        if result.masks is None:
            continue
        for box, mask in zip(result.boxes, result.masks.xy):
            class_id = int(box.cls)
            confidence = float(box.conf)
            if confidence < confidence_threshold:
                continue
            if class_id == 0 and confidence > max_sample_conf:
                best_sample_mask = np.array(mask)
                max_sample_conf = confidence
            elif class_id == 1 and confidence > max_roller_conf:
                best_roller_mask = np.array(mask)
                max_roller_conf = confidence

    is_touching = False
    current_roller_center = None

    if best_sample_mask is not None and best_roller_mask is not None:
        roller_size = np.max(pdist(best_roller_mask))
        touch_threshold = touch_threshold_factor * roller_size
        min_edge_distance = np.min(cdist(best_sample_mask, best_roller_mask))
        if min_edge_distance <= touch_threshold:
            is_touching = True

        current_roller_center = np.mean(best_roller_mask, axis=0)
        roller_centers.append(current_roller_center)

        print(f"Frame {frame_count}: Touching = {'Yes' if is_touching else 'No'}")
        print(f"Frame {frame_count}: Minimum Edge Distance = {min_edge_distance:.2f} pixels")
        print(f"Frame {frame_count}: Roller Size = {roller_size:.2f} pixels")
    else:
        print(f"Frame {frame_count}: One or both objects not detected.")
    
    # Determine average vector
    average_vector = None
    if len(roller_centers) >= 2:
        average_vector = roller_centers[-1] - roller_centers[0]

    # Track touching with motion direction control
    if is_touching:
        if gap_frames > 0 and gap_frames <= max_gap:
            touching_frames += gap_frames
        gap_frames = 0

        if average_vector is not None and np.linalg.norm(average_vector) > 0:
            if len(motion_vectors) > 0:
                last_vector = motion_vectors[-1]
                angle_change = angle_between(last_vector, average_vector)

                if angle_change > angle_threshold:
                    if touching_frames > 0:
                        touching_frames_list.append(touching_frames)
                        print(f"Deposition Layer Completed (Direction Changed): {touching_frames} consecutive touching frames")
                    touching_frames = 1
                    motion_vectors = [average_vector]
                else:
                    touching_frames += 1
                    motion_vectors.append(average_vector)
            else:
                touching_frames += 1
                motion_vectors.append(average_vector)
        else:
            touching_frames += 1
    else:
        if previous_touching_state:
            gap_frames = 1
        elif gap_frames > 0:
            gap_frames += 1

        if gap_frames > max_gap:
            if touching_frames > 0:
                touching_frames_list.append(touching_frames)
                print(f"Deposition Layer Completed: {touching_frames} consecutive touching frames")
            touching_frames = 0
            gap_frames = 0
            motion_vectors = []

    previous_touching_state = is_touching
    time.sleep(0.3)

# Final pass check
if touching_frames > 0:
    touching_frames_list.append(touching_frames)
    print(f"Deposition Layer Completed: {touching_frames} consecutive touching frames")

# Print all detected passes before filtering
if touching_frames_list:
    print("\nAll detected deposition passes before filtering:")
    print(f"{touching_frames_list}")

# Filter short passes
if touching_frames_list:
    max_pass = max(touching_frames_list)
    min_frames_per_pass = 0.2 * max_pass
    touching_frames_list = [pass_frames for pass_frames in touching_frames_list if pass_frames >= min_frames_per_pass]

# Compute statistics
if touching_frames_list:
    avg_touching_frames = sum(touching_frames_list) / len(touching_frames_list)
    roller_speed = sample_length_mm / (avg_touching_frames * frame_time_s)

    print("\n--- Deposition Statistics ---")
    print(f"Total deposition passes: {len(touching_frames_list)}")
    print(f"Touching frames per pass: {touching_frames_list}")
    print(f"Average touching frames: {avg_touching_frames:.2f} frames")
    print(f"Computed roller speed: {roller_speed:.2f} mm/s")

cap.release()
# Out:
# Total frames: 3300, FPS: 30.00, Frame time: 0.033s
#
# 0: 384x480 1 Nozzle, 33.4ms
# Speed: 2.2ms preprocess, 33.4ms inference, 59.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 1: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 6.8ms
# Speed: 2.5ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 2: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 7.2ms
# Speed: 2.1ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 4: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 5: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 6: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 7: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 5.1ms
# Speed: 1.0ms preprocess, 5.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 8: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 20.6ms
# Speed: 2.9ms preprocess, 20.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 9: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 14.0ms
# Speed: 2.3ms preprocess, 14.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 10: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 27.6ms
# Speed: 5.8ms preprocess, 27.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 11: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 23.7ms
# Speed: 3.6ms preprocess, 23.7ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 12: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 29.2ms
# Speed: 3.6ms preprocess, 29.2ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 13: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 30.4ms
# Speed: 4.1ms preprocess, 30.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 14: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 26.5ms
# Speed: 2.8ms preprocess, 26.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 15: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 29.4ms
# Speed: 2.7ms preprocess, 29.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 16: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.0ms
# Speed: 3.0ms preprocess, 24.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 17: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 27.0ms
# Speed: 3.6ms preprocess, 27.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 18: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.1ms
# Speed: 2.9ms preprocess, 21.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 19: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 20: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 26.2ms
# Speed: 3.5ms preprocess, 26.2ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 21: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 35.8ms
# Speed: 4.8ms preprocess, 35.8ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 22: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.4ms
# Speed: 2.4ms preprocess, 21.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 23: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 25.4ms
# Speed: 2.6ms preprocess, 25.4ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 24: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 25.6ms
# Speed: 3.6ms preprocess, 25.6ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 25: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.7ms
# Speed: 3.1ms preprocess, 24.7ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 26: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 25.9ms
# Speed: 3.6ms preprocess, 25.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 27: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 22.8ms
# Speed: 2.7ms preprocess, 22.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 28: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 25.0ms
# Speed: 0.9ms preprocess, 25.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 29: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 27.5ms
# Speed: 4.7ms preprocess, 27.5ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 30: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 26.9ms
# Speed: 3.4ms preprocess, 26.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 31: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.6ms
# Speed: 3.0ms preprocess, 21.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 32: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.7ms
# Speed: 2.3ms preprocess, 21.7ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 33: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 29.6ms
# Speed: 3.4ms preprocess, 29.6ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 34: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 39.6ms
# Speed: 3.2ms preprocess, 39.6ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 35: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.3ms
# Speed: 4.1ms preprocess, 24.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 36: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 28.6ms
# Speed: 3.5ms preprocess, 28.6ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 37: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 31.7ms
# Speed: 2.4ms preprocess, 31.7ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 38: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 23.4ms
# Speed: 2.3ms preprocess, 23.4ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 39: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.3ms
# Speed: 3.5ms preprocess, 21.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 40: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 22.7ms
# Speed: 3.8ms preprocess, 22.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 41: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 23.3ms
# Speed: 3.9ms preprocess, 23.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 42: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.9ms
# Speed: 3.5ms preprocess, 24.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 43: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.4ms
# Speed: 3.4ms preprocess, 24.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 44: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.2ms
# Speed: 3.1ms preprocess, 24.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 45: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 27.1ms
# Speed: 3.1ms preprocess, 27.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 46: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 22.7ms
# Speed: 3.5ms preprocess, 22.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 47: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 26.1ms
# Speed: 3.1ms preprocess, 26.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 48: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.5ms
# Speed: 2.5ms preprocess, 21.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 49: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.4ms
# Speed: 3.1ms preprocess, 21.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 50: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 29.8ms
# Speed: 3.6ms preprocess, 29.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 51: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 27.1ms
# Speed: 3.2ms preprocess, 27.1ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 52: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 27.2ms
# Speed: 3.7ms preprocess, 27.2ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 53: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 22.5ms
# Speed: 4.7ms preprocess, 22.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 54: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.2ms
# Speed: 3.9ms preprocess, 24.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 55: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.1ms
# Speed: 4.6ms preprocess, 24.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 56: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 23.3ms
# Speed: 3.5ms preprocess, 23.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 57: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 26.0ms
# Speed: 3.7ms preprocess, 26.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 58: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 25.2ms
# Speed: 2.4ms preprocess, 25.2ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 59: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 22.8ms
# Speed: 3.6ms preprocess, 22.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 60: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 22.6ms
# Speed: 2.8ms preprocess, 22.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 61: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.9ms
# Speed: 2.8ms preprocess, 21.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 62: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.9ms
# Speed: 3.3ms preprocess, 24.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 63: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.8ms
# Speed: 3.3ms preprocess, 24.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 64: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 21.7ms
# Speed: 3.1ms preprocess, 21.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 65: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 27.3ms
# Speed: 3.4ms preprocess, 27.3ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 66: One or both objects not detected.
#
# 0: 384x480 (no detections), 47.8ms
# Speed: 3.2ms preprocess, 47.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 67: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.8ms
# Speed: 3.2ms preprocess, 21.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 68: One or both objects not detected.
#
# 0: 384x480 (no detections), 23.5ms
# Speed: 3.5ms preprocess, 23.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 69: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 2.5ms preprocess, 21.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 70: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.7ms
# Speed: 3.0ms preprocess, 21.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 71: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.5ms
# Speed: 4.1ms preprocess, 21.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 72: One or both objects not detected.
#
# 0: 384x480 (no detections), 23.5ms
# Speed: 4.3ms preprocess, 23.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 73: One or both objects not detected.
#
# 0: 384x480 (no detections), 23.1ms
# Speed: 4.2ms preprocess, 23.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 74: One or both objects not detected.
#
# 0: 384x480 (no detections), 23.5ms
# Speed: 5.4ms preprocess, 23.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 75: One or both objects not detected.
#
# 0: 384x480 (no detections), 27.3ms
# Speed: 3.8ms preprocess, 27.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 76: One or both objects not detected.
#
# 0: 384x480 (no detections), 26.8ms
# Speed: 4.1ms preprocess, 26.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 77: One or both objects not detected.
#
# 0: 384x480 (no detections), 23.1ms
# Speed: 3.5ms preprocess, 23.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 78: One or both objects not detected.
#
# 0: 384x480 (no detections), 22.8ms
# Speed: 3.5ms preprocess, 22.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 79: One or both objects not detected.
#
# 0: 384x480 (no detections), 25.7ms
# Speed: 3.7ms preprocess, 25.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 80: One or both objects not detected.
#
# 0: 384x480 (no detections), 31.0ms
# Speed: 3.7ms preprocess, 31.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 81: One or both objects not detected.
#
# 0: 384x480 (no detections), 31.2ms
# Speed: 3.4ms preprocess, 31.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 82: One or both objects not detected.
#
# 0: 384x480 (no detections), 29.7ms
# Speed: 3.5ms preprocess, 29.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 83: One or both objects not detected.
#
# 0: 384x480 (no detections), 25.6ms
# Speed: 3.9ms preprocess, 25.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 84: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.9ms
# Speed: 3.1ms preprocess, 24.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 85: One or both objects not detected.
#
# 0: 384x480 (no detections), 33.1ms
# Speed: 4.2ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 86: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.6ms
# Speed: 3.4ms preprocess, 21.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 87: One or both objects not detected.
#
# 0: 384x480 (no detections), 25.5ms
# Speed: 9.7ms preprocess, 25.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 88: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.5ms
# Speed: 2.3ms preprocess, 21.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 89: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.8ms
# Speed: 3.2ms preprocess, 24.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 90: One or both objects not detected.
#
# 0: 384x480 (no detections), 28.0ms
# Speed: 3.2ms preprocess, 28.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 91: One or both objects not detected.
#
# 0: 384x480 (no detections), 22.6ms
# Speed: 2.9ms preprocess, 22.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 92: One or both objects not detected.
#
# 0: 384x480 (no detections), 26.5ms
# Speed: 2.8ms preprocess, 26.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 93: One or both objects not detected.
#
# 0: 384x480 (no detections), 25.8ms
# Speed: 4.3ms preprocess, 25.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 94: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.4ms
# Speed: 4.2ms preprocess, 24.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 95: One or both objects not detected.
#
# 0: 384x480 (no detections), 30.8ms
# Speed: 3.6ms preprocess, 30.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 96: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.6ms
# Speed: 3.3ms preprocess, 21.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 97: One or both objects not detected.
#
# 0: 384x480 (no detections), 23.0ms
# Speed: 3.7ms preprocess, 23.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 98: One or both objects not detected.
#
# 0: 384x480 (no detections), 22.0ms
# Speed: 3.5ms preprocess, 22.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 99: One or both objects not detected.
#
# 0: 384x480 (no detections), 23.0ms
# Speed: 2.2ms preprocess, 23.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 100: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.7ms
# Speed: 3.2ms preprocess, 21.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 101: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.5ms
# Speed: 5.8ms preprocess, 24.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 102: One or both objects not detected.
#
# 0: 384x480 (no detections), 25.7ms
# Speed: 4.6ms preprocess, 25.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 103: One or both objects not detected.
#
# 0: 384x480 (no detections), 26.9ms
# Speed: 4.4ms preprocess, 26.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 104: One or both objects not detected.
#
# 0: 384x480 (no detections), 25.6ms
# Speed: 4.7ms preprocess, 25.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 105: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.9ms
# Speed: 3.8ms preprocess, 21.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 106: One or both objects not detected.
#
# 0: 384x480 (no detections), 23.3ms
# Speed: 3.1ms preprocess, 23.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 107: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.4ms
# Speed: 3.8ms preprocess, 24.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 108: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 3.1ms preprocess, 21.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 109: One or both objects not detected.
#
# 0: 384x480 (no detections), 25.0ms
# Speed: 3.0ms preprocess, 25.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 110: One or both objects not detected.
#
# 0: 384x480 (no detections), 23.5ms
# Speed: 6.2ms preprocess, 23.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 111: One or both objects not detected.
#
# 0: 384x480 (no detections), 26.9ms
# Speed: 2.9ms preprocess, 26.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 112: One or both objects not detected.
#
# 0: 384x480 (no detections), 35.9ms
# Speed: 4.9ms preprocess, 35.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 113: One or both objects not detected.
#
# 0: 384x480 (no detections), 25.0ms
# Speed: 4.7ms preprocess, 25.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 114: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.2ms
# Speed: 3.7ms preprocess, 24.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 115: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.4ms
# Speed: 4.5ms preprocess, 24.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 116: One or both objects not detected.
#
# 0: 384x480 (no detections), 29.5ms
# Speed: 3.8ms preprocess, 29.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 117: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.9ms
# Speed: 3.0ms preprocess, 24.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 118: One or both objects not detected.
#
# 0: 384x480 (no detections), 22.2ms
# Speed: 2.9ms preprocess, 22.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 119: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.8ms
# Speed: 3.3ms preprocess, 21.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 120: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.5ms
# Speed: 3.2ms preprocess, 21.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 121: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.8ms
# Speed: 3.6ms preprocess, 21.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 122: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.7ms
# Speed: 3.9ms preprocess, 21.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 123: One or both objects not detected.
#
# 0: 384x480 (no detections), 22.8ms
# Speed: 3.4ms preprocess, 22.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 124: One or both objects not detected.
#
# 0: 384x480 (no detections), 27.3ms
# Speed: 4.3ms preprocess, 27.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 125: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.3ms
# Speed: 3.5ms preprocess, 24.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 126: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.9ms
# Speed: 4.5ms preprocess, 24.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 127: One or both objects not detected.
#
# 0: 384x480 (no detections), 26.9ms
# Speed: 4.9ms preprocess, 26.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 128: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.4ms
# Speed: 2.7ms preprocess, 21.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 129: One or both objects not detected.
#
# 0: 384x480 (no detections), 21.3ms
# Speed: 2.6ms preprocess, 21.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 130: One or both objects not detected.
#
# 0: 384x480 (no detections), 31.6ms
# Speed: 2.9ms preprocess, 31.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 131: One or both objects not detected.
#
# 0: 384x480 (no detections), 24.1ms
# Speed: 3.5ms preprocess, 24.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 132: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 24.2ms
# Speed: 5.5ms preprocess, 24.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 133: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 23.9ms
# Speed: 3.7ms preprocess, 23.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 134: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 32.6ms
# Speed: 5.1ms preprocess, 32.6ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 135: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 26.5ms
# Speed: 3.7ms preprocess, 26.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 136: One or both objects not detected.
#
# 0: 384x480 1 Nozzle, 26.6ms
# Speed: 3.9ms preprocess, 26.6ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 137: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.6ms
# Speed: 3.1ms preprocess, 21.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 138: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.8ms
# Speed: 4.3ms preprocess, 23.8ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 139: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.2ms
# Speed: 3.7ms preprocess, 26.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 140: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 3.4ms preprocess, 21.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 141: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.4ms
# Speed: 3.1ms preprocess, 21.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 142: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.2ms
# Speed: 4.4ms preprocess, 25.2ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 143: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 27.6ms
# Speed: 4.2ms preprocess, 27.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 144: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.7ms
# Speed: 3.8ms preprocess, 25.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 145: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.6ms
# Speed: 4.1ms preprocess, 25.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 146: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.7ms
# Speed: 3.8ms preprocess, 25.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 147: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.3ms
# Speed: 4.1ms preprocess, 24.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 148: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 3.2ms preprocess, 21.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 149: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.0ms
# Speed: 4.3ms preprocess, 26.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 150: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.6ms
# Speed: 3.8ms preprocess, 25.6ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 151: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.6ms
# Speed: 3.8ms preprocess, 24.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 152: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.2ms
# Speed: 4.0ms preprocess, 23.2ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 153: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.5ms
# Speed: 3.9ms preprocess, 25.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 154: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.8ms
# Speed: 3.8ms preprocess, 23.8ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 155: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.0ms
# Speed: 4.2ms preprocess, 25.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 156: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.8ms
# Speed: 4.0ms preprocess, 24.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 157: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.9ms
# Speed: 4.0ms preprocess, 26.9ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 158: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.6ms
# Speed: 4.7ms preprocess, 24.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 159: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.4ms
# Speed: 4.1ms preprocess, 25.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 160: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 30.5ms
# Speed: 4.2ms preprocess, 30.5ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 161: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.6ms
# Speed: 4.8ms preprocess, 23.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 162: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.2ms
# Speed: 4.5ms preprocess, 26.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 163: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.0ms
# Speed: 4.1ms preprocess, 22.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 164: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.1ms
# Speed: 3.5ms preprocess, 24.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 165: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 31.4ms
# Speed: 6.0ms preprocess, 31.4ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 166: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.9ms
# Speed: 4.2ms preprocess, 24.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 167: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 37.6ms
# Speed: 6.8ms preprocess, 37.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 168: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.3ms
# Speed: 3.0ms preprocess, 21.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 169: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.5ms
# Speed: 3.9ms preprocess, 22.5ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 170: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.4ms
# Speed: 2.6ms preprocess, 21.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 171: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.5ms
# Speed: 3.6ms preprocess, 24.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 172: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 28.7ms
# Speed: 3.8ms preprocess, 28.7ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 173: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.4ms
# Speed: 2.7ms preprocess, 21.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 174: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.7ms
# Speed: 5.5ms preprocess, 25.7ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 175: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.1ms
# Speed: 3.8ms preprocess, 26.1ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 176: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.9ms
# Speed: 3.8ms preprocess, 23.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 177: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.1ms
# Speed: 4.2ms preprocess, 24.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 178: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 27.0ms
# Speed: 4.2ms preprocess, 27.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 179: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.6ms
# Speed: 5.4ms preprocess, 25.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 180: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.6ms
# Speed: 4.1ms preprocess, 23.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 181: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 38.7ms
# Speed: 3.5ms preprocess, 38.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 182: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 34.1ms
# Speed: 3.8ms preprocess, 34.1ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 183: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.5ms
# Speed: 4.2ms preprocess, 25.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 184: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.1ms
# Speed: 3.7ms preprocess, 24.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 185: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.2ms
# Speed: 3.7ms preprocess, 22.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 186: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.5ms
# Speed: 4.0ms preprocess, 23.5ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 187: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.3ms
# Speed: 4.1ms preprocess, 26.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 188: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.7ms
# Speed: 5.2ms preprocess, 26.7ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 189: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.3ms
# Speed: 4.4ms preprocess, 23.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 190: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.2ms
# Speed: 4.1ms preprocess, 23.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 191: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.9ms
# Speed: 3.8ms preprocess, 24.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 192: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.6ms
# Speed: 5.3ms preprocess, 26.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 193: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.4ms
# Speed: 4.4ms preprocess, 22.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 194: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.1ms
# Speed: 4.2ms preprocess, 26.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 195: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.2ms
# Speed: 4.1ms preprocess, 26.2ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 196: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.9ms
# Speed: 6.2ms preprocess, 25.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 197: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.8ms
# Speed: 6.6ms preprocess, 22.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 198: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.6ms
# Speed: 4.8ms preprocess, 23.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 199: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.3ms
# Speed: 5.0ms preprocess, 25.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 200: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.2ms
# Speed: 4.2ms preprocess, 22.2ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 201: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.3ms
# Speed: 4.1ms preprocess, 26.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 202: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 36.9ms
# Speed: 4.1ms preprocess, 36.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 203: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.4ms
# Speed: 4.0ms preprocess, 25.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 204: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.1ms
# Speed: 3.2ms preprocess, 24.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 205: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 21.5ms
# Speed: 7.4ms preprocess, 21.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 206: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 27.0ms
# Speed: 4.1ms preprocess, 27.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 207: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 26.3ms
# Speed: 4.1ms preprocess, 26.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 208: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.5ms
# Speed: 6.3ms preprocess, 25.5ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 209: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.5ms
# Speed: 4.7ms preprocess, 25.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 210: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 23.2ms
# Speed: 3.8ms preprocess, 23.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 211: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.6ms
# Speed: 4.2ms preprocess, 25.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 212: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.2ms
# Speed: 3.0ms preprocess, 22.2ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 213: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 25.0ms
# Speed: 3.8ms preprocess, 25.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 214: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 22.4ms
# Speed: 5.1ms preprocess, 22.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 215: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 27.7ms
# Speed: 3.6ms preprocess, 27.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 216: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 24.5ms
# Speed: 4.1ms preprocess, 24.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 217: One or both objects not detected.
#
# 0: 384x480 1 Roller, 1 Nozzle, 31.2ms
# Speed: 4.0ms preprocess, 31.2ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 218: One or both objects not detected.
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 36.5ms
# Speed: 3.7ms preprocess, 36.5ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 219: One or both objects not detected.
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.5ms
# Speed: 3.5ms preprocess, 25.5ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 220: Touching = Yes
# Frame 220: Minimum Edge Distance = 1.93 pixels
# Frame 220: Roller Size = 25.54 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 2.8ms preprocess, 21.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 221: One or both objects not detected.
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.3ms
# Speed: 3.7ms preprocess, 26.3ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 222: Touching = Yes
# Frame 222: Minimum Edge Distance = 0.97 pixels
# Frame 222: Roller Size = 27.08 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.4ms
# Speed: 6.1ms preprocess, 25.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 223: Touching = Yes
# Frame 223: Minimum Edge Distance = 0.00 pixels
# Frame 223: Roller Size = 27.65 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.6ms
# Speed: 3.8ms preprocess, 23.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 224: Touching = Yes
# Frame 224: Minimum Edge Distance = 0.00 pixels
# Frame 224: Roller Size = 28.56 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.5ms
# Speed: 3.8ms preprocess, 25.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 225: Touching = Yes
# Frame 225: Minimum Edge Distance = 0.00 pixels
# Frame 225: Roller Size = 28.97 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.9ms
# Speed: 3.9ms preprocess, 23.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 226: Touching = Yes
# Frame 226: Minimum Edge Distance = 0.00 pixels
# Frame 226: Roller Size = 28.97 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.5ms
# Speed: 4.1ms preprocess, 25.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 227: Touching = Yes
# Frame 227: Minimum Edge Distance = 0.97 pixels
# Frame 227: Roller Size = 27.51 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.0ms
# Speed: 3.9ms preprocess, 24.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 228: Touching = Yes
# Frame 228: Minimum Edge Distance = 0.97 pixels
# Frame 228: Roller Size = 25.74 pixels
# Deposition Layer Completed (Direction Changed): 8 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 27.2ms
# Speed: 4.1ms preprocess, 27.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 229: Touching = Yes
# Frame 229: Minimum Edge Distance = 0.00 pixels
# Frame 229: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.1ms
# Speed: 4.6ms preprocess, 25.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 230: Touching = Yes
# Frame 230: Minimum Edge Distance = 0.00 pixels
# Frame 230: Roller Size = 29.86 pixels
# Deposition Layer Completed (Direction Changed): 2 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.4ms
# Speed: 3.8ms preprocess, 24.4ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 231: Touching = Yes
# Frame 231: Minimum Edge Distance = 0.97 pixels
# Frame 231: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 33.9ms
# Speed: 8.0ms preprocess, 33.9ms inference, 13.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 232: Touching = Yes
# Frame 232: Minimum Edge Distance = 0.97 pixels
# Frame 232: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 27.1ms
# Speed: 3.7ms preprocess, 27.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 233: Touching = Yes
# Frame 233: Minimum Edge Distance = 0.97 pixels
# Frame 233: Roller Size = 26.03 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.4ms
# Speed: 4.1ms preprocess, 25.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 234: Touching = Yes
# Frame 234: Minimum Edge Distance = 0.97 pixels
# Frame 234: Roller Size = 29.40 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.0ms
# Speed: 4.8ms preprocess, 23.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 235: Touching = Yes
# Frame 235: Minimum Edge Distance = 0.97 pixels
# Frame 235: Roller Size = 29.40 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.3ms
# Speed: 4.0ms preprocess, 24.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 236: Touching = Yes
# Frame 236: Minimum Edge Distance = 0.00 pixels
# Frame 236: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.6ms
# Speed: 4.1ms preprocess, 23.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 237: Touching = Yes
# Frame 237: Minimum Edge Distance = 0.00 pixels
# Frame 237: Roller Size = 26.54 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.6ms
# Speed: 4.6ms preprocess, 25.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 238: Touching = Yes
# Frame 238: Minimum Edge Distance = 2.16 pixels
# Frame 238: Roller Size = 26.54 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.0ms
# Speed: 3.6ms preprocess, 26.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 239: Touching = Yes
# Frame 239: Minimum Edge Distance = 1.37 pixels
# Frame 239: Roller Size = 28.56 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.3ms
# Speed: 4.3ms preprocess, 26.3ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 240: Touching = Yes
# Frame 240: Minimum Edge Distance = 0.00 pixels
# Frame 240: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.4ms
# Speed: 4.0ms preprocess, 26.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 241: Touching = Yes
# Frame 241: Minimum Edge Distance = 0.97 pixels
# Frame 241: Roller Size = 28.97 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 22.7ms
# Speed: 4.0ms preprocess, 22.7ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 242: Touching = Yes
# Frame 242: Minimum Edge Distance = 0.97 pixels
# Frame 242: Roller Size = 29.40 pixels
# Deposition Layer Completed (Direction Changed): 12 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.9ms
# Speed: 3.7ms preprocess, 25.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 243: Touching = Yes
# Frame 243: Minimum Edge Distance = 0.97 pixels
# Frame 243: Roller Size = 29.40 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 28.2ms
# Speed: 3.8ms preprocess, 28.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 244: Touching = Yes
# Frame 244: Minimum Edge Distance = 0.00 pixels
# Frame 244: Roller Size = 31.80 pixels
# Deposition Layer Completed (Direction Changed): 2 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.0ms
# Speed: 3.6ms preprocess, 25.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 245: Touching = Yes
# Frame 245: Minimum Edge Distance = 0.00 pixels
# Frame 245: Roller Size = 28.18 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.2ms
# Speed: 4.0ms preprocess, 25.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 246: Touching = Yes
# Frame 246: Minimum Edge Distance = 0.97 pixels
# Frame 246: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.7ms
# Speed: 4.5ms preprocess, 25.7ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 247: Touching = Yes
# Frame 247: Minimum Edge Distance = 0.97 pixels
# Frame 247: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.4ms
# Speed: 3.2ms preprocess, 23.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 248: Touching = Yes
# Frame 248: Minimum Edge Distance = 1.37 pixels
# Frame 248: Roller Size = 27.51 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.6ms
# Speed: 4.3ms preprocess, 26.6ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 249: Touching = Yes
# Frame 249: Minimum Edge Distance = 0.00 pixels
# Frame 249: Roller Size = 30.95 pixels
# Deposition Layer Completed (Direction Changed): 5 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.1ms
# Speed: 3.2ms preprocess, 25.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 250: Touching = Yes
# Frame 250: Minimum Edge Distance = 0.97 pixels
# Frame 250: Roller Size = 27.83 pixels
# Deposition Layer Completed (Direction Changed): 1 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.0ms
# Speed: 3.4ms preprocess, 26.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 251: Touching = Yes
# Frame 251: Minimum Edge Distance = 0.97 pixels
# Frame 251: Roller Size = 29.40 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.4ms
# Speed: 3.7ms preprocess, 24.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 252: Touching = Yes
# Frame 252: Minimum Edge Distance = 0.00 pixels
# Frame 252: Roller Size = 31.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.4ms
# Speed: 3.9ms preprocess, 24.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 253: Touching = Yes
# Frame 253: Minimum Edge Distance = 0.00 pixels
# Frame 253: Roller Size = 33.29 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 27.3ms
# Speed: 4.2ms preprocess, 27.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 254: Touching = Yes
# ...
# Frame 3246: Touching = Yes
# Frame 3246: Minimum Edge Distance = 0.97 pixels
# Frame 3246: Roller Size = 31.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.8ms
# Speed: 2.5ms preprocess, 21.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3247: Touching = Yes
# Frame 3247: Minimum Edge Distance = 0.00 pixels
# Frame 3247: Roller Size = 28.18 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 27.8ms
# Speed: 2.4ms preprocess, 27.8ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3248: Touching = Yes
# Frame 3248: Minimum Edge Distance = 0.00 pixels
# Frame 3248: Roller Size = 28.18 pixels
# Deposition Layer Completed (Direction Changed): 44 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 28.2ms
# Speed: 3.5ms preprocess, 28.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3249: Touching = Yes
# Frame 3249: Minimum Edge Distance = 0.00 pixels
# Frame 3249: Roller Size = 33.29 pixels
# Deposition Layer Completed (Direction Changed): 1 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.1ms
# Speed: 3.5ms preprocess, 24.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3250: Touching = Yes
# Frame 3250: Minimum Edge Distance = 0.00 pixels
# Frame 3250: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.4ms
# Speed: 4.0ms preprocess, 24.4ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3251: Touching = Yes
# Frame 3251: Minimum Edge Distance = 0.00 pixels
# Frame 3251: Roller Size = 33.29 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 22.0ms
# Speed: 3.7ms preprocess, 22.0ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3252: Touching = Yes
# Frame 3252: Minimum Edge Distance = 0.00 pixels
# Frame 3252: Roller Size = 32.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.2ms
# Speed: 3.7ms preprocess, 21.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3253: Touching = Yes
# Frame 3253: Minimum Edge Distance = 0.97 pixels
# Frame 3253: Roller Size = 32.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.0ms
# Speed: 4.0ms preprocess, 25.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3254: Touching = Yes
# Frame 3254: Minimum Edge Distance = 0.00 pixels
# Frame 3254: Roller Size = 32.88 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.5ms
# Speed: 3.5ms preprocess, 24.5ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3255: Touching = Yes
# Frame 3255: Minimum Edge Distance = 0.97 pixels
# Frame 3255: Roller Size = 29.02 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 29.2ms
# Speed: 3.6ms preprocess, 29.2ms inference, 12.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3256: Touching = Yes
# Frame 3256: Minimum Edge Distance = 0.00 pixels
# Frame 3256: Roller Size = 31.91 pixels
# Deposition Layer Completed (Direction Changed): 7 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.3ms
# Speed: 3.2ms preprocess, 21.3ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3257: Touching = Yes
# Frame 3257: Minimum Edge Distance = 0.00 pixels
# Frame 3257: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 27.1ms
# Speed: 3.6ms preprocess, 27.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3258: Touching = Yes
# Frame 3258: Minimum Edge Distance = 0.00 pixels
# Frame 3258: Roller Size = 31.80 pixels
# Deposition Layer Completed (Direction Changed): 2 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.4ms
# Speed: 3.7ms preprocess, 24.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3259: Touching = Yes
# Frame 3259: Minimum Edge Distance = 0.00 pixels
# Frame 3259: Roller Size = 28.18 pixels
# Deposition Layer Completed (Direction Changed): 1 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.9ms
# Speed: 3.3ms preprocess, 23.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3260: Touching = Yes
# Frame 3260: Minimum Edge Distance = 0.00 pixels
# Frame 3260: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 22.8ms
# Speed: 4.5ms preprocess, 22.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3261: Touching = Yes
# Frame 3261: Minimum Edge Distance = 0.97 pixels
# Frame 3261: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 32.5ms
# Speed: 3.3ms preprocess, 32.5ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3262: Touching = Yes
# Frame 3262: Minimum Edge Distance = 0.00 pixels
# Frame 3262: Roller Size = 32.13 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.1ms
# Speed: 2.3ms preprocess, 24.1ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3263: Touching = Yes
# Frame 3263: Minimum Edge Distance = 0.97 pixels
# Frame 3263: Roller Size = 33.51 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.0ms
# Speed: 3.1ms preprocess, 24.0ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3264: Touching = Yes
# Frame 3264: Minimum Edge Distance = 1.37 pixels
# Frame 3264: Roller Size = 32.00 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.6ms
# Speed: 2.7ms preprocess, 23.6ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3265: Touching = Yes
# Frame 3265: Minimum Edge Distance = 0.00 pixels
# Frame 3265: Roller Size = 33.29 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.9ms
# Speed: 2.7ms preprocess, 21.9ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3266: Touching = Yes
# Frame 3266: Minimum Edge Distance = 0.97 pixels
# Frame 3266: Roller Size = 31.91 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.9ms
# Speed: 4.0ms preprocess, 25.9ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3267: Touching = Yes
# Frame 3267: Minimum Edge Distance = 0.00 pixels
# Frame 3267: Roller Size = 32.88 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.6ms
# Speed: 3.4ms preprocess, 24.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3268: Touching = Yes
# Frame 3268: Minimum Edge Distance = 0.00 pixels
# Frame 3268: Roller Size = 32.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.3ms
# Speed: 4.5ms preprocess, 23.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3269: Touching = Yes
# Frame 3269: Minimum Edge Distance = 0.00 pixels
# Frame 3269: Roller Size = 31.91 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.6ms
# Speed: 3.7ms preprocess, 25.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3270: Touching = Yes
# Frame 3270: Minimum Edge Distance = 0.00 pixels
# Frame 3270: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 27.7ms
# Speed: 3.5ms preprocess, 27.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3271: Touching = Yes
# Frame 3271: Minimum Edge Distance = 1.37 pixels
# Frame 3271: Roller Size = 31.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 29.2ms
# Speed: 4.1ms preprocess, 29.2ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3272: Touching = Yes
# Frame 3272: Minimum Edge Distance = 0.97 pixels
# Frame 3272: Roller Size = 32.13 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.6ms
# Speed: 3.1ms preprocess, 21.6ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3273: Touching = Yes
# Frame 3273: Minimum Edge Distance = 0.97 pixels
# Frame 3273: Roller Size = 29.86 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.9ms
# Speed: 3.6ms preprocess, 25.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3274: Touching = Yes
# Frame 3274: Minimum Edge Distance = 0.00 pixels
# Frame 3274: Roller Size = 35.15 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.0ms
# Speed: 3.4ms preprocess, 21.0ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3275: Touching = Yes
# Frame 3275: Minimum Edge Distance = 0.00 pixels
# Frame 3275: Roller Size = 35.15 pixels
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 26.0ms
# Speed: 3.6ms preprocess, 26.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3276: Touching = Yes
# Frame 3276: Minimum Edge Distance = 0.97 pixels
# Frame 3276: Roller Size = 33.29 pixels
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 23.4ms
# Speed: 4.4ms preprocess, 23.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3277: Touching = Yes
# Frame 3277: Minimum Edge Distance = 0.97 pixels
# Frame 3277: Roller Size = 37.20 pixels
# Deposition Layer Completed (Direction Changed): 18 consecutive touching frames
#
# 0: 384x480 2 Samples, 1 Roller, 1 Nozzle, 25.1ms
# Speed: 3.6ms preprocess, 25.1ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3278: Touching = Yes
# Frame 3278: Minimum Edge Distance = 0.00 pixels
# Frame 3278: Roller Size = 37.61 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.6ms
# Speed: 3.5ms preprocess, 25.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3279: Touching = Yes
# Frame 3279: Minimum Edge Distance = 0.97 pixels
# Frame 3279: Roller Size = 36.44 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 22.5ms
# Speed: 4.8ms preprocess, 22.5ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3280: Touching = Yes
# Frame 3280: Minimum Edge Distance = 0.00 pixels
# Frame 3280: Roller Size = 38.50 pixels
# Deposition Layer Completed (Direction Changed): 3 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.2ms
# Speed: 5.8ms preprocess, 26.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3281: Touching = Yes
# Frame 3281: Minimum Edge Distance = 1.37 pixels
# Frame 3281: Roller Size = 39.96 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 27.4ms
# Speed: 3.6ms preprocess, 27.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3282: Touching = Yes
# Frame 3282: Minimum Edge Distance = 0.97 pixels
# Frame 3282: Roller Size = 34.92 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.2ms
# Speed: 2.7ms preprocess, 23.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3283: Touching = Yes
# Frame 3283: Minimum Edge Distance = 1.93 pixels
# Frame 3283: Roller Size = 32.49 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.9ms
# Speed: 3.9ms preprocess, 25.9ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3284: Touching = Yes
# Frame 3284: Minimum Edge Distance = 0.00 pixels
# Frame 3284: Roller Size = 35.77 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 29.3ms
# Speed: 3.2ms preprocess, 29.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3285: Touching = Yes
# Frame 3285: Minimum Edge Distance = 1.93 pixels
# Frame 3285: Roller Size = 34.05 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 21.4ms
# Speed: 3.2ms preprocess, 21.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3286: Touching = Yes
# Frame 3286: Minimum Edge Distance = 1.93 pixels
# Frame 3286: Roller Size = 33.82 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 31.3ms
# Speed: 6.5ms preprocess, 31.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3287: Touching = Yes
# Frame 3287: Minimum Edge Distance = 0.00 pixels
# Frame 3287: Roller Size = 36.09 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.1ms
# Speed: 4.3ms preprocess, 24.1ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3288: Touching = Yes
# Frame 3288: Minimum Edge Distance = 0.97 pixels
# Frame 3288: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.8ms
# Speed: 5.2ms preprocess, 24.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3289: Touching = Yes
# Frame 3289: Minimum Edge Distance = 0.97 pixels
# Frame 3289: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 22.8ms
# Speed: 3.5ms preprocess, 22.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3290: Touching = Yes
# Frame 3290: Minimum Edge Distance = 0.97 pixels
# Frame 3290: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 23.8ms
# Speed: 3.4ms preprocess, 23.8ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3291: Touching = Yes
# Frame 3291: Minimum Edge Distance = 0.97 pixels
# Frame 3291: Roller Size = 39.46 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.4ms
# Speed: 4.2ms preprocess, 26.4ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3292: Touching = Yes
# Frame 3292: Minimum Edge Distance = 0.97 pixels
# Frame 3292: Roller Size = 39.46 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 22.3ms
# Speed: 4.3ms preprocess, 22.3ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3293: Touching = Yes
# Frame 3293: Minimum Edge Distance = 0.97 pixels
# Frame 3293: Roller Size = 36.20 pixels
# Deposition Layer Completed (Direction Changed): 13 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.4ms
# Speed: 3.2ms preprocess, 24.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3294: Touching = Yes
# Frame 3294: Minimum Edge Distance = 0.97 pixels
# Frame 3294: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.5ms
# Speed: 3.7ms preprocess, 26.5ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3295: Touching = Yes
# Frame 3295: Minimum Edge Distance = 0.97 pixels
# Frame 3295: Roller Size = 36.20 pixels
# Deposition Layer Completed (Direction Changed): 2 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 22.3ms
# Speed: 3.1ms preprocess, 22.3ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3296: Touching = Yes
# Frame 3296: Minimum Edge Distance = 0.97 pixels
# Frame 3296: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3297: Touching = Yes
# Frame 3297: Minimum Edge Distance = 0.97 pixels
# Frame 3297: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 25.3ms
# Speed: 3.9ms preprocess, 25.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3298: Touching = Yes
# Frame 3298: Minimum Edge Distance = 0.97 pixels
# Frame 3298: Roller Size = 36.20 pixels
# Deposition Layer Completed (Direction Changed): 3 consecutive touching frames
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 35.1ms
# Speed: 4.1ms preprocess, 35.1ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3299: Touching = Yes
# Frame 3299: Minimum Edge Distance = 0.97 pixels
# Frame 3299: Roller Size = 36.20 pixels
#
# 0: 384x480 1 Sample, 1 Roller, 1 Nozzle, 26.6ms
# Speed: 3.6ms preprocess, 26.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 480)
# Frame 3300: Touching = Yes
# Frame 3300: Minimum Edge Distance = 0.97 pixels
# Frame 3300: Roller Size = 36.20 pixels
# Deposition Layer Completed: 3 consecutive touching frames
#
# All detected deposition passes before filtering:
# [8, 2, 12, 2, 5, 1, 5, 22, 1, 11, 1, 2, 1, 17, 1, 5, 2, 1, 10, 1, 5, 1, 19, 14, 11, 15, 1, 1, 13, 1, 16, 1, 32, 1, 27, 17, 14, 8, 20, 1, 5, 1, 12, 2, 1, 1, 21, 1, 23, 1, 23, 16, 12, 8, 1, 2, 1, 6, 1, 13, 1, 9, 1, 5, 1, 1, 6, 1, 12, 28, 1, 5, 1, 13, 2, 11, 1, 3, 14, 9, 1, 8, 2, 15, 1, 15, 1, 7, 17, 1, 6, 39, 1, 6, 4, 1, 1, 13, 10, 2, 6, 2, 4, 1, 2, 24, 1, 4, 1, 6, 1, 26, 3, 23, 1, 15, 4, 12, 18, 1, 1, 2, 2, 16, 2, 16, 13, 2, 1, 3, 7, 6, 6, 34, 5, 12, 10, 2, 6, 2, 37, 1, 44, 1, 7, 2, 1, 18, 3, 13, 2, 3, 3]
#
# --- Deposition Statistics ---
# Total deposition passes: 52
# Touching frames per pass: [12, 22, 11, 17, 10, 19, 14, 11, 15, 13, 16, 32, 27, 17, 14, 20, 12, 21, 23, 23, 16, 12, 13, 9, 12, 28, 13, 11, 14, 9, 15, 15, 17, 39, 13, 10, 24, 26, 23, 15, 12, 18, 16, 16, 13, 34, 12, 10, 37, 44, 18, 13]
# Average touching frames: 17.81 frames
# Computed roller speed: 353.78 mm/s
